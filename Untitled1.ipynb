# %% [markdown]
# <a href="https://colab.research.google.com/github/kietazkid/K/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url='Book2.csv'
dataframe=pd.read_csv(url)
dataframe.head(21)
# Out:
#     NO      MSSV            NAME    KHOA  SCORE
# 0    1  20146490  BÀNH THỊ BÉ TƯ  CƠ KHÍ      1
# 1    2  20146492   LÊ VĂN KHUYẾT  CƠ KHÍ      5
# 2    3  20146494  NGUYỄN VĂN TÀN  CƠ KHÍ      6
# 3    4  20146496   LÊ VĂN KHUYẾT  CƠ KHÍ      7
# 4    5  20146498        TRẦN NGŨ  CƠ KHÍ      6
# 5    6  20146500          LÊ TAM  CƠ KHÍ      3
# 6    7  20146502           LÝ TỨ  CƠ KHÍ      9
# 7    8  20146504     BÙI THỊ LỤC  CƠ KHÍ     10
# 8    9  20146506     ĐỆ VĂN THẤT  CƠ KHÍ      2
# 9   10  20146508         CAO BÁT  CƠ KHÍ      5
# 10  11  20146510   HUỲNH CỬU CỬU  CƠ KHÍ      9
# 11  12  20146512    THẬP VĂN CỪU  CƠ KHÍ      8
# 12  13  20146514  NGUYỄN THỊ SÓI  CƠ KHÍ      4
# 13  14  20146516    TRẦN VĂN CÁI  CƠ KHÍ      5
# 14  15  20146518     TRẦN THỊ NA  CƠ KHÍ      7
# 15  16  20146520   LÊ THỊ CẨM TÚ  CƠ KHÍ      2
# 16  17  20146522      MAI VĂN TẠ  CƠ KHÍ      1
# 17  18  20146524     LÊ THỊ THẮM  CƠ KHÍ      8
# 18  19  20146526    BA THỊ BÉ BA  CƠ KHÍ      9

# %%
import pandas as pd
url='Book2.csv'
dataframe=pd.read_csv(url)
dataframe.loc[0:10]
# Out:
#     NO      MSSV            NAME    KHOA  SCORE
# 0    1  20146490  BÀNH THỊ BÉ TƯ  CƠ KHÍ      1
# 1    2  20146492   LÊ VĂN KHUYẾT  CƠ KHÍ      5
# 2    3  20146494  NGUYỄN VĂN TÀN  CƠ KHÍ      6
# 3    4  20146496   LÊ VĂN KHUYẾT  CƠ KHÍ      7
# 4    5  20146498        TRẦN NGŨ  CƠ KHÍ      6
# 5    6  20146500          LÊ TAM  CƠ KHÍ      3
# 6    7  20146502           LÝ TỨ  CƠ KHÍ      9
# 7    8  20146504     BÙI THỊ LỤC  CƠ KHÍ     10
# 8    9  20146506     ĐỆ VĂN THẤT  CƠ KHÍ      2
# 9   10  20146508         CAO BÁT  CƠ KHÍ      5
# 10  11  20146510   HUỲNH CỬU CỬU  CƠ KHÍ      9

# %%
import pandas as pd
url='Book2.csv'
dataframe=pd.read_csv(url)
dataframe= dataframe.set_index(dataframe['NAME'])
dataframe.loc['LÝ TỨ']
# Out:
# NO              7
# MSSV     20146502
# NAME        LÝ TỨ
# KHOA       CƠ KHÍ
# SCORE           9
# Name: LÝ TỨ, dtype: object

# %%
import pandas as pd
url='Book2.csv'
dataframe=pd.read_csv(url)
dataframe[dataframe['NAME']=='LÝ TỨ'].head(10)
# Out:
#    NO      MSSV   NAME    KHOA  SCORE
# 6   7  20146502  LÝ TỨ  CƠ KHÍ      9

# %%
import pandas as pd
url='Book3.csv'
dataframe=pd.read_csv(url)
dataframe[(dataframe['KHOA']=='CKM')&(dataframe['NAME']=='LÝ TỨ')]
# Out:
# Empty DataFrame
# Columns: [NO, MSSV, NAME, KHOA, SCORE]
# Index: []

# %%
import pandas as pd
url='Book3.csv'
dataframe=pd.read_csv(url)
dataframe['KHOA'].replace('CKM','CO KHI').head(10)
# Out:
# 0        CƠ KHÍ
# 1        CO KHI
# 2        CƠ KHÍ
# 3          ĐIỆN
# 4    THOI TRANG
# 5        CƠ KHÍ
# 6        CƠ KHÍ
# 7        CO KHI
# 8        CƠ KHÍ
# 9    THOI TRANG
# Name: KHOA, dtype: object

# %%
import pandas as pd
url='Book3.csv'
dataframe=pd.read_csv(url)
dataframe.replace('CKM','CO KHI').head(10)
# Out:
#    NO      MSSV            NAME        KHOA  SCORE
# 0   1  20146490  BÀNH THỊ BÉ TƯ      CƠ KHÍ      1
# 1   2  20146492   LÊ VĂN KHUYẾT      CO KHI      5
# 2   3  20146494  NGUYỄN VĂN TÀN      CƠ KHÍ      6
# 3   4  20146496   LÊ VĂN KHUYẾT        ĐIỆN      7
# 4   5  20146498        TRẦN NGŨ  THOI TRANG      6
# 5   6  20146500          LÊ TAM      CƠ KHÍ      3
# 6   7  20146502           LÝ TỨ      CƠ KHÍ      9
# 7   8  20146504     BÙI THỊ LỤC      CO KHI     10
# 8   9  20146506     ĐỆ VĂN THẤT      CƠ KHÍ      2
# 9  10  20146508         CAO BÁT  THOI TRANG      5

# %%
import pandas as pd
url='Book3.csv'
dataframe=pd.read_csv(url)
print('điểm cao nhất',dataframe['SCORE'].max())
# Out:
# điểm cao nhất 10

# %%
import pandas as pd
url='Book3.csv'
dataframe=pd.read_csv(url)
dataframe['KHOA'].unique()
dataframe['KHOA'].value_counts()
# Out:
# CƠ KHÍ        10
# THOI TRANG     4
# CKM            3
# ĐIỆN           2
# Name: KHOA, dtype: int64

# %%
import pandas as pd
url='Book2.csv'
dataframe=pd.read_csv(url)
dataframe.drop('MSSV',axis=1).head(10)
# Out:
#    NO            NAME    KHOA  SCORE
# 0   1  BÀNH THỊ BÉ TƯ  CƠ KHÍ      1
# 1   2   LÊ VĂN KHUYẾT  CƠ KHÍ      5
# 2   3  NGUYỄN VĂN TÀN  CƠ KHÍ      6
# 3   4   LÊ VĂN KHUYẾT  CƠ KHÍ      7
# 4   5        TRẦN NGŨ  CƠ KHÍ      6
# 5   6          LÊ TAM  CƠ KHÍ      3
# 6   7           LÝ TỨ  CƠ KHÍ      9
# 7   8     BÙI THỊ LỤC  CƠ KHÍ     10
# 8   9     ĐỆ VĂN THẤT  CƠ KHÍ      2
# 9  10         CAO BÁT  CƠ KHÍ      5

# %%
import pandas as pd
url='Book2.csv'
dataframe=pd.read_csv(url)
dataframe.drop(['MSSV','KHOA'],axis=1).head(10)
# Out:
#    NO            NAME  SCORE
# 0   1  BÀNH THỊ BÉ TƯ      1
# 1   2   LÊ VĂN KHUYẾT      5
# 2   3  NGUYỄN VĂN TÀN      6
# 3   4   LÊ VĂN KHUYẾT      7
# 4   5        TRẦN NGŨ      6
# 5   6          LÊ TAM      3
# 6   7           LÝ TỨ      9
# 7   8     BÙI THỊ LỤC     10
# 8   9     ĐỆ VĂN THẤT      2
# 9  10         CAO BÁT      5

# %%
import pandas as pd
url='Book2.csv'
dataframe=pd.read_csv(url)
dataframe.drop(dataframe.columns[2:4],axis=1).head(10)
# Out:
#    NO      MSSV  SCORE
# 0   1  20146490      1
# 1   2  20146492      5
# 2   3  20146494      6
# 3   4  20146496      7
# 4   5  20146498      6
# 5   6  20146500      3
# 6   7  20146502      9
# 7   8  20146504     10
# 8   9  20146506      2
# 9  10  20146508      5

# %%
import pandas as pd
url='Book3.csv'
dataframe=pd.read_csv(url)
dataframe[dataframe['KHOA']!='CKM'].head(10)
# Out:
#     NO      MSSV            NAME        KHOA  SCORE
# 0    1  20146490  BÀNH THỊ BÉ TƯ      CƠ KHÍ      1
# 2    3  20146494  NGUYỄN VĂN TÀN      CƠ KHÍ      6
# 3    4  20146496   LÊ VĂN KHUYẾT        ĐIỆN      7
# 4    5  20146498        TRẦN NGŨ  THOI TRANG      6
# 5    6  20146500          LÊ TAM      CƠ KHÍ      3
# 6    7  20146502           LÝ TỨ      CƠ KHÍ      9
# 8    9  20146506     ĐỆ VĂN THẤT      CƠ KHÍ      2
# 9   10  20146508         CAO BÁT  THOI TRANG      5
# 10  11  20146510   HUỲNH CỬU CỬU      CƠ KHÍ      9
# 12  13  20146514  NGUYỄN THỊ SÓI      CƠ KHÍ      4

# %%
import pandas as pd
url='Book3.csv'
dataframe=pd.read_csv(url)
dataframe[dataframe['SCORE']!=2].head(10)
# Out:
#     NO      MSSV            NAME        KHOA  SCORE
# 0    1  20146490  BÀNH THỊ BÉ TƯ      CƠ KHÍ      1
# 1    2  20146492   LÊ VĂN KHUYẾT         CKM      5
# 2    3  20146494  NGUYỄN VĂN TÀN      CƠ KHÍ      6
# 3    4  20146496   LÊ VĂN KHUYẾT        ĐIỆN      7
# 4    5  20146498        TRẦN NGŨ  THOI TRANG      6
# 5    6  20146500          LÊ TAM      CƠ KHÍ      3
# 6    7  20146502           LÝ TỨ      CƠ KHÍ      9
# 7    8  20146504     BÙI THỊ LỤC         CKM     10
# 9   10  20146508         CAO BÁT  THOI TRANG      5
# 10  11  20146510   HUỲNH CỬU CỬU      CƠ KHÍ      9

# %%
import pandas as pd
url='Book3.csv'
dataframe=pd.read_csv(url)
dataframe[dataframe.index!=2].head(10)
# Out:
#     NO      MSSV            NAME        KHOA  SCORE
# 0    1  20146490  BÀNH THỊ BÉ TƯ      CƠ KHÍ      1
# 1    2  20146492   LÊ VĂN KHUYẾT         CKM      5
# 3    4  20146496   LÊ VĂN KHUYẾT        ĐIỆN      7
# 4    5  20146498        TRẦN NGŨ  THOI TRANG      6
# 5    6  20146500          LÊ TAM      CƠ KHÍ      3
# 6    7  20146502           LÝ TỨ      CƠ KHÍ      9
# 7    8  20146504     BÙI THỊ LỤC         CKM     10
# 8    9  20146506     ĐỆ VĂN THẤT      CƠ KHÍ      2
# 9   10  20146508         CAO BÁT  THOI TRANG      5
# 10  11  20146510   HUỲNH CỬU CỬU      CƠ KHÍ      9

# %%
import pandas as pd
url='Book3.csv'
dataframe=pd.read_csv(url)
dataframe[dataframe.index!=2].head(10)
# Out:
#     NO      MSSV            NAME        KHOA  SCORE
# 0    1  20146490  BÀNH THỊ BÉ TƯ      CƠ KHÍ      1
# 1    2  20146492   LÊ VĂN KHUYẾT         CKM      5
# 3    4  20146496   LÊ VĂN KHUYẾT        ĐIỆN      7
# 4    5  20146498        TRẦN NGŨ  THOI TRANG      6
# 5    6  20146500          LÊ TAM      CƠ KHÍ      3
# 6    7  20146502           LÝ TỨ      CƠ KHÍ      9
# 7    8  20146504     BÙI THỊ LỤC         CKM     10
# 8    9  20146506     ĐỆ VĂN THẤT      CƠ KHÍ      2
# 9   10  20146508         CAO BÁT  THOI TRANG      5
# 10  11  20146510   HUỲNH CỬU CỬU      CƠ KHÍ      9

# %%
import pandas as pd
url='Book2.csv'
dataframe=pd.read_csv(url)
dataframe.drop_duplicates().head(10)
# Out:
#    NO      MSSV            NAME    KHOA  SCORE
# 0   1  20146490  BÀNH THỊ BÉ TƯ  CƠ KHÍ      1
# 1   2  20146492   LÊ VĂN KHUYẾT  CƠ KHÍ      5
# 2   3  20146494  NGUYỄN VĂN TÀN  CƠ KHÍ      6
# 3   4  20146496   LÊ VĂN KHUYẾT  CƠ KHÍ      7
# 4   5  20146498        TRẦN NGŨ  CƠ KHÍ      6
# 5   6  20146500          LÊ TAM  CƠ KHÍ      3
# 6   7  20146502           LÝ TỨ  CƠ KHÍ      9
# 7   8  20146504     BÙI THỊ LỤC  CƠ KHÍ     10
# 8   9  20146506     ĐỆ VĂN THẤT  CƠ KHÍ      2
# 9  10  20146508         CAO BÁT  CƠ KHÍ      5

# %%
import pandas as pd
url='Book3.csv'
dataframe=pd.read_csv(url)
dataframe.groupby('KHOA').count()
# Out:
#             NO  MSSV  NAME  SCORE
# KHOA
# CKM          3     3     3      3
# CƠ KHÍ      10    10    10     10
# THOI TRANG   4     4     4      4
# ĐIỆN         2     2     2      2

# %%
import pandas as pd
url='Book3.csv'
dataframe=pd.read_csv(url)
dataframe.groupby(['KHOA','SCORE']).count()
# Out:
#                   NO  MSSV  NAME
# KHOA       SCORE
# CKM        5       1     1     1
#            8       1     1     1
#            10      1     1     1
# CƠ KHÍ     1       2     2     2
#            2       2     2     2
#            3       1     1     1
#            4       1     1     1
#            6       1     1     1
#            7       1     1     1
#            9       2     2     2
# THOI TRANG 5       2     2     2
#            6       1     1     1
#            8       1     1     1
# ĐIỆN       7       1     1     1
#            9       1     1     1

# %%
from pandas._libs.tslibs import period
from os import times_result
import pandas as pd
import numpy as np
time_index=pd.date_range('01/01/2023',periods=100000,freq='30s')
dataframe=pd.DataFrame(index=time_index)
dataframe['Acess_Amount']=np.random.randint(1,10,100000)
dataframe.resample('W').sum()
# Out:
#             Acess_Amount
# 2023-01-01         14347
# 2023-01-08        100403
# 2023-01-15        101138
# 2023-01-22        101391
# 2023-01-29        100727
# 2023-02-05         82109

# %%
from pandas._libs.tslibs import period
from os import times_result
import pandas as pd
import numpy as np
time_index=pd.date_range('01/01/2023',periods=100000,freq='30s')
dataframe=pd.DataFrame(index=time_index)
dataframe['Acess_Amount']=np.random.randint(1,10,100000)
dataframe.resample('2W').sum()
# Out:
#             Acess_Amount
# 2023-01-01         14417
# 2023-01-15        202126
# 2023-01-29        201202
# 2023-02-12         82277

# %%
from pandas._libs.tslibs import period
from os import times_result
import pandas as pd
import numpy as np
time_index=pd.date_range('01/01/2023',periods=100000,freq='30s')
dataframe=pd.DataFrame(index=time_index)
dataframe['Acess_Amount']=np.random.randint(1,10,100000)
dataframe.resample('M').sum()
# Out:
#             Acess_Amount
# 2023-01-31        445976
# 2023-02-28         53411

# %%
import pandas as pd
url='medals.csv'
data=pd.read_csv(url)
dataframe=pd.read_csv(url)
dataframe[dataframe['Medal']=='Gold'].head(10)
# Out:
#     Year      City       Sport       Discipline  NOC                Event  \
# 1   1924  Chamonix     Skating   Figure skating  AUT           individual
# 2   1924  Chamonix     Skating   Figure skating  AUT                pairs
# 4   1924  Chamonix  Ice Hockey       Ice Hockey  CAN           ice hockey
# 7   1924  Chamonix     Skating    Speed skating  FIN               10000m
# 9   1924  Chamonix     Skating    Speed skating  FIN                1500m
# 10  1924  Chamonix     Skating    Speed skating  FIN                5000m
# 14  1924  Chamonix     Skating    Speed skating  FIN  combined (4 events)
# 20  1924  Chamonix     Curling          Curling  GBR              curling
# 30  1924  Chamonix      Skiing  Cross Country S  NOR                 18km
# 33  1924  Chamonix      Skiing  Cross Country S  NOR                 50km
#
#    Event gender Medal
# 1             W  Gold
# 2             X  Gold
# 4             M  Gold
# 7             M  Gold
# 9             M  Gold
# ...

# %%
pip install scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 KB 18.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894088 sha256=8eb029ea3f153aac85c17135921fd32dadec4c2ddbcea6e74e594e36312aeffa
#   Stored in directory: /root/.cache/pip/wheels/2c/04/80/7eefb1a2de7d36aefd06432fab2a1486caf0a0596a7067391a
# Successfully built scikit-fuzzy
# ...

# %%
import pandas as pd
url='http://winterolympicsmedals.com/medals.csv'
data=pd.read_csv(url)
data[data['NOC']=='CAN'].head(2300)
data[(data['Event']=='individual') & (data['Medal']=='Gold')].head(2300)
# Out:
#       Year            City      Sport       Discipline  NOC       Event  \
# 1     1924        Chamonix    Skating   Figure skating  AUT  individual
# 36    1924        Chamonix     Skiing  Nordic Combined  NOR  individual
# 44    1924        Chamonix    Skating   Figure skating  SWE  individual
# 62    1928      St. Moritz    Skating   Figure skating  NOR  individual
# 73    1928      St. Moritz     Skiing  Nordic Combined  NOR  individual
# ...    ...             ...        ...              ...  ...         ...
# 2037  2002  Salt Lake City    Skating   Figure skating  USA  individual
# 2087  2006           Turin  Bobsleigh         Skeleton  CAN  individual
# 2190  2006           Turin    Skating   Figure skating  JPN  individual
# 2241  2006           Turin    Skating   Figure skating  RUS  individual
# 2258  2006           Turin  Bobsleigh         Skeleton  SUI  individual
#
#      Event gender Medal
# 1               W  Gold
# 36              M  Gold
# 44              M  Gold
# ...

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl
food = ctrl.Antecedent(np.arange(0,11,1),'food')
service = ctrl.Antecedent(np.arange(0,11,1),'sevice')
tip = ctrl.Consequent(np.arange(10,31,1),'tip')
food['poor']=fuzz.trimf(food.universe,[0,0,5])
food['average']=fuzz.trimf(food.universe,[0,5,10])
food['good']=fuzz.trimf(food.universe,[5,10,10])
service['poor']=fuzz.trimf(service.universe,[0,0,5])
service['average']=fuzz.trimf(service.universe,[0,5,10])
service['good']=fuzz.trimf(service.universe,[5,10,10])
tip['poor']=fuzz.trimf(tip.universe,[0,0,20])
tip['average']=fuzz.trimf(tip.universe,[0,20,30])
tip['good']=fuzz.trimf(tip.universe,[20,30,30])
food.view()
service.view()
tip.view()
service['average'].view()
rule1=ctrl.Rule(food['poor']& service['poor'],tip['less'])
rule2=ctrl.Rule(food['poor']&service['average'],tip['tb'])
rule3=ctrl.Rule(food['poor']&service['good'],tip['cao'])
rule4=ctrl.Rule(food['average']&service['poor'],tip['less'])
rule5=ctrl.Rule(food['average']&service['average'],tip['tb'])
rule6=ctrl.Rule(food['average']&service['good'],tip['cao'])
rule7=ctrl.Rule(food['good']&service['poor'],tip['less'])
rule8=ctrl.Rule(food['good']&service['average'],tip['tb'])
rule9=ctrl.Rule(food['good']&service['good'],tip['cao'])

tipping_ctrl= ctrl.controlsystem([rule1, rule2, rule3, rule4, rule5, rule6, rule7, rule7, rule8, rule9])
tipping=ctrl.ControlSystemSimulation(tipping_ctrl)
tipping.input['service']=9.8
tipping.input['food']=7.0
tipping.compute()
print(tipping.output['tip'])
tip.view(sim= tipping)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-a7880a25a15d> in <module>
#      18 tip.view()
#      19 service['average'].view()
# ---> 20 rule1=ctrl.Rule(food['poor']& service['poor'],tip['less'])
#      21 rule2=ctrl.Rule(food['poor']&service['average'],tip['tb'])
#      22 rule3=ctrl.Rule(food['poor']&service['good'],tip['cao'])
#
# /usr/local/lib/python3.8/dist-packages/skfuzzy/control/fuzzyvariable.py in __getitem__(self, key)
#      80                 else:
#      81                     options += "'" + str(available_key) + "'; "
# ---> 82             raise ValueError("Membership function '{0}' does not exist for "
#      83                              "{1} {2}.\n"
#      84                              "Available options: {3}".format(
#
# ValueError: Membership function 'less' does not exist for Consequent tip.
# ...

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl
time = ctrl.Antecedent(np.arange(10,301,1),'time')
rice = ctrl.Antecedent(np.arange(100,2001,1),'rice')
power = ctrl.Consequent(np.arange(0,101,1),'power')
time['veryfat']=fuzz.trimf(time.universe,[10,15,15])
time['fat']=fuzz.trimf(time.universe,[15,35,50])
time['tb']=fuzz.trimf(time.universe,[50,75,100])
time['slow']=fuzz.trimf(time.universe,[100,150,200])
time['veryslow']=fuzz.trimf(time.universe,[200,250,300])
rice['ratit']=fuzz.trimf(rice.universe,[100,200,200])
rice['it']=fuzz.trimf(rice.universe,[200,500,500])
rice['tb']=fuzz.trimf(rice.universe,[500,1200,1200])
rice['nhieu']=fuzz.trimf(rice.universe,[1200,1500,1500])
rice['ratbnhieu']=fuzz.trimf(rice.universe,[1500,1900,2000])

power['ratcao']=fuzz.trimf(power.universe,[0,10,20])
power['cao']=fuzz.trimf(power.universe,[10,30,40])
power['tb']=fuzz.trimf(power.universe,[30,45,60])
power['thap']=fuzz.trimf(power.universe,[40,50,80])
power['ratthap']=fuzz.trimf(power.universe,[50,75,100])

time.view()
rice.view()
power.view()

# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt 

time = ctrl.Antecedent(np.arange(10,301,1), 'time')
rice = ctrl.Antecedent(np.arange(100,2001,1), 'rice')
power = ctrl.Consequent(np.arange(0,101,1),'power')

#ham lien thuoc
time['ultra fast'] = fuzz.trimf(time.universe, [10,10,90]) 
time['very fast'] = fuzz.trimf(time.universe, [10,90,170])
time['fast'] = fuzz.trimf(time.universe, [90,170,250])
time['slow'] = fuzz.trimf(time.universe, [170,250,300])
time['very slow'] = fuzz.trimf(time.universe, [250,300,300])

rice['least'] = fuzz.trimf(rice.universe, [100,100,575])
rice['less'] = fuzz.trimf(rice.universe, [100,575,1050])
rice['average'] = fuzz.trimf(rice.universe, [575,1050,1525])
rice['much'] = fuzz.trimf(rice.universe, [1050,1525,2000])
rice['most'] = fuzz.trimf(rice.universe, [1525,2000,2000])

power['very low'] = fuzz.trimf(power.universe, [0,20,20])
power['low'] = fuzz.trimf(power.universe, [0,40,40])
power['average'] = fuzz.trimf(power.universe, [0,60,60])
power['high'] = fuzz.trimf(power.universe, [0,80,80])
power['very high'] = fuzz.trimf(power.universe, [0,100,100])

#make rule
rule1 = ctrl.Rule(time['ultra fast'] & rice['least'], power['very low'])
rule2 = ctrl.Rule(time['ultra fast'] & rice['less'], power['very low'])
rule3 = ctrl.Rule(time['ultra fast'] & rice['average'], power['low'])
rule4 = ctrl.Rule(time['ultra fast'] & rice['much'], power['low'])
rule5 = ctrl.Rule(time['ultra fast'] & rice['most'], power['average'])

rule6 = ctrl.Rule(time['very fast'] & rice['least'], power['low'])
rule7 = ctrl.Rule(time['very fast'] & rice['less'], power['low'])
rule8 = ctrl.Rule(time['very fast'] & rice['average'], power['average'])
rule9 = ctrl.Rule(time['very fast'] & rice['much'], power['average'])
rule10 = ctrl.Rule(time['very fast'] & rice['most'], power['high'])

rule11 = ctrl.Rule(time['fast'] & rice['least'], power['average'])
rule12 = ctrl.Rule(time['fast'] & rice['less'], power['average'])
rule13 = ctrl.Rule(time['fast'] & rice['average'], power['high'])
rule14 = ctrl.Rule(time['fast'] & rice['much'], power['high'])
rule15 = ctrl.Rule(time['fast'] & rice['most'], power['very high'])

rule16 = ctrl.Rule(time['slow'] & rice['least'], power['high'])
rule17 = ctrl.Rule(time['slow'] & rice['less'], power['high'])
rule18 = ctrl.Rule(time['slow'] & rice['average'], power['very high'])
rule19 = ctrl.Rule(time['slow'] & rice['much'], power['very high'])
rule20 = ctrl.Rule(time['slow'] & rice['most'], power['very high'])

rule21 = ctrl.Rule(time['very slow'] & rice['least'], power['high'])
rule22 = ctrl.Rule(time['very slow'] & rice['less'], power['high'])
rule23 = ctrl.Rule(time['very slow'] & rice['average'], power['very high'])
rule24 = ctrl.Rule(time['very slow'] & rice['much'], power['very high'])
rule25 = ctrl.Rule(time['very slow'] & rice['most'], power['very high'])

time.view()
rice.view()
power.view()
power_ctrl = ctrl.ControlSystem([rule1, rule2, rule3, rule4, rule5, rule6, rule7, rule8, rule9, rule10, rule11, rule12,
rule13, rule14, rule15, rule16,rule17,rule18,rule19,rule20,rule21,rule22,rule23,rule24,rule25])
tipping=ctrl.ControlSystemSimulation(power_ctrl)
tipping.input['time']=150
tipping.input['rice']=700
tipping.compute()
print(tipping.output['power'])
power.view(sim= tipping)
# Out:
# 43.576653747023734
